# %%
#Importing modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Obtaining and understand data

# %%
#importing data set employee_dataset.csv
data=pd.read_csv("employee_dataset.csv")
df=pd.DataFrame(data)
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %% [markdown]
# # Data prepration

# %%
#name of all columns in dataset
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %% [markdown]
# # deleting columns which is not usefull for data analysis
#  1.MarriedID
#  2.FromDiversityJobFairID
#  3.Termd
#  4.HispanicLatino

# %%
df.drop(['TermReason','FromDiversityJobFairID','Termd','HispanicLatino'],axis=1,inplace=True)
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  Salary  PositionID  ...  \
# ...

# %%
#finding null values in dataset
#we have found the most of null values are present in DateOfTermination column and ManagerId column
df.isna().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# Salary                          0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ManagerID                       8
# RecruitmentSource               0
# PerformanceScore                0
# EngagementSurvey                0
# ...

# %%
#removing DateofTermination colum becouse it countain 207 null values in dataset
df.drop(['DateofTermination'],axis=1,inplace=True)
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  Salary  PositionID  ...  \
# ...

# %%
#ManagerID column also countain null values we are deleteing the null values only
df.dropna(inplace=True)
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  Salary  PositionID  ...  \
# ...

# %%
#now there is no null values present in dataset
df.isna().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# Salary                        0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# RaceDesc                      0
# DateofHire                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# PerformanceScore              0
# EngagementSurvey              0
# EmpSatisfaction               0
# SpecialProjectsCount          0
# LastPerformanceReview_Date    0
# ...

# %%
df.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# Salary                          int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# RaceDesc                       object
# DateofHire                     object
# EmploymentStatus               object
# Department                     object
# ManagerName                    object
# ManagerID                     float64
# RecruitmentSource              object
# PerformanceScore               object
# ...

# %%
#Converting LastPerformanceReview_Date & DateofHire in datetime formate
df['LastPerformanceReview_Date']= pd.to_datetime(df['LastPerformanceReview_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 303 entries, 0 to 310
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               303 non-null    object
#  1   EmpID                       303 non-null    int64
#  2   MarriedID                   303 non-null    int64
#  3   MaritalStatusID             303 non-null    int64
#  4   GenderID                    303 non-null    int64
#  5   EmpStatusID                 303 non-null    int64
#  6   DeptID                      303 non-null    int64
#  7   PerfScoreID                 303 non-null    int64
#  8   Salary                      303 non-null    int64
#  9   PositionID                  303 non-null    int64
#  10  Position                    303 non-null    object
#  11  State                       303 non-null    object
#  12  Zip                         303 non-null    int64
# ...

# %%
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  Salary  PositionID  ...  \
# ...

# %%
#changing coumn name sex to gender
df.rename(columns={'Sex': 'Gender'}, inplace=True)

# %%
df[['MaritalStatusID','Salary','Absences','EngagementSurvey']].describe()
# Out:
#        MaritalStatusID         Salary    Absences  EngagementSurvey
# count       303.000000     303.000000  303.000000        303.000000
# mean          0.815182   69292.316832   10.267327          4.106139
# std           0.941413   25406.092767    5.883906          0.794589
# min           0.000000   45046.000000    1.000000          1.120000
# 25%           0.000000   55633.000000    5.000000          3.675000
# 50%           1.000000   62910.000000   10.000000          4.280000
# 75%           1.000000   72331.000000   15.000000          4.700000
# max           4.000000  250000.000000   20.000000          5.000000

# %% [markdown]
# #  Exploratory Data Analysis

# %%
#i have divided data in 2 part fiest 'df1' for EDA process and second 'df2' for machine learning
df1=df[['Employee_Name','EmpID',
          'Gender','MaritalDesc','DOB',
          'Department','Position',
          'EmploymentStatus','PerformanceScore',
          'Salary','ManagerName',
          'State','DateofHire',
          'RaceDesc','RecruitmentSource',
          'SpecialProjectsCount','Absences']]
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#                 Employee_Name  EmpID Gender MaritalDesc       DOB  \
# 0         Adinolfi, Wilson  K  10026     M       Single  07/10/83
# 1    Ait Sidi, Karthikeyan     10084     M      Married  05/05/75
# 2           Akinkuolie, Sarah  10196      F     Married  09/19/88
# 3                Alagbe,Trina  10088      F     Married  09/27/88
# 4            Anderson, Carol   10069      F    Divorced  09/08/89
# ..                        ...    ...    ...         ...       ...
# 298            Woodson, Jason  10135     M       Single  05/11/85
# 299        Ybarra, Catherine   10301      F      Single  05/04/82
# 300          Zamora, Jennifer  10010      F      Single  08/30/79
# 301               Zhou, Julia  10043      F      Single  02/24/79
# 302             Zima, Colleen  10271      F     Widowed  08/17/78
#
#             Department                  Position        EmploymentStatus  \
# 0    Production          Production Technician I                  Active
# ...

# %%
# df1.loc[(df1['RecruitmentSource'].str.startswith('I')),
#                     ['Employee_Name','Position','RecruitmentSource','PerformanceScore']]

# %% [markdown]
# # Q1. Total number of employee gender wise?

# %%
ge=df1['Gender'].value_counts()
ge
# Out:
# F     171
# M     132
# Name: Gender, dtype: int64

# %%
ge.plot.bar(color="#FF00FF",title='employee description graph')
# Out:
# <AxesSubplot:title={'center':'employee description graph'}>

# %%
df1['DateofHire'].min()
# minimum employees hire on 1/10/2011
# Out:
# '1/10/2011'

# %%
df1['DateofHire'].max()
# maximum employees hire on 9/6/2016
# Out:
# '9/6/2016'

# %% [markdown]
# # observation
# 1. minimum hiring of employees is in 1 octomber 2011
# 2. maximum hiring of employees is in 9 june 2016
# 3. maximum number of employees are female 172 and male employees are 132

# %% [markdown]
# # Q2. Maritial status of employee?

# %%
md=pd.DataFrame(df1['MaritalDesc'].value_counts())
md
#on the basis of maritial status we can also predict the mental perssure and performance of employee 
#1. if the employee is single then we can say the person will have less mental pressure so he/she can perform better
#2. if the employee is married then we can say they are more focused and perform better because they have responsibility of there family
#3. if divorced then they will perfrom good/bad both on there mental condition
#4. if seprated then they will perform sometime good or sometime bad on there mental condition
#5. if widowed then they will try to give there best because of there need and condition
# Out:
#            MaritalDesc
# Single             132
# Married            122
# Divorced            30
# Separated           11
# Widowed              8

# %%
md.plot.bar(color="red")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q3. Employee count on the basis of department?

# %%
dp=pd.DataFrame(df1['Department'].value_counts())
dp
# Out:
#                       Department
# Production                   201
# IT/IS                         50
# Sales                         31
# Software Engineering          11
# Admin Offices                  9
# Executive Office               1

# %%
dp.plot.barh(color="Green")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q4. Employee count  on there status of employment?

# %%
Es=pd.DataFrame(df1['EmploymentStatus'].value_counts())
Es
# from this we have seen that from 303 employees only 199 is an active employees 
# so we can assume that we have to give an increment to only 199 employee
# Out:
#                         EmploymentStatus
# Active                               199
# Voluntarily Terminated                88
# Terminated for Cause                  16

# %%
Es.plot.bar(Color="Purple")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1439: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   return ax.bar(x, y, w, bottom=start, log=log, **kwds)
# <AxesSubplot:>

# %% [markdown]
# # Q5. number of employee performance wise and  have Active status ?

# %%
pf=pd.DataFrame(df1[['EmploymentStatus','PerformanceScore']][df1['EmploymentStatus']=='Active'].value_counts())
pf
# From 199 employee 183 employee ge increament in there salary
# Out:
#                                       0
# EmploymentStatus PerformanceScore
# Active           Fully Meets        155
#                  Exceeds             28
#                  Needs Improvement    8
#                  PIP                  8

# %%
pf.plot.barh(color="#bc5090", title="active emp performance")
# Out:
# <AxesSubplot:title={'center':'active emp performance'}, ylabel='EmploymentStatus,PerformanceScore'>

# %% [markdown]
# # Q6. how many employees have performance_score is Exceeds on the basis of there department?

# %%
pd.DataFrame(df1['Department'][df1['PerformanceScore']=='Exceeds'].value_counts())
#in this we have found that who is working in production and it/is has more number of fullymeet and other will have less number so 
# we can say that production and IT/IS candidate will perform good in next review also so they will get hike in salary also.
# Out:
#                       Department
# Production                    26
# IT/IS                          6
# Sales                          2
# Software Engineering           2

# %% [markdown]
# # Q7. employee whose salary is more then or equal to 100000 and who will get hike if performance score is meets?

# %%
sa=pd.DataFrame(df1[['Employee_Name','Position','EmploymentStatus','PerformanceScore','RecruitmentSource','Salary']]
                [df1['Salary']>=100000])
sa.reset_index(drop=True,inplace=True)
sa
# Out:
#                Employee_Name                  Position  \
# 0   Ait Sidi, Karthikeyan                      Sr. DBA
# 1              Becker, Renee    Database Administrator
# 2               Booth, Frank      Enterprise Architect
# 3          Boutwell, Bonalyn            Sr. Accountant
# 4           Carr, Claudia  N                   Sr. DBA
# 5          Champaigne, Brian               BI Director
# 6             Corleone, Vito    Director of Operations
# 7          Del Bosque, Keyla         Software Engineer
# 8              Dougall, Eric      IT Manager - Support
# 9                Foss, Jason               IT Director
# 10             Goble, Taisha    Database Administrator
# 11           Houlihan, Debra         Director of Sales
# 12          Johnson, Noelle     Database Administrator
# 13               King, Janet           President & CEO
# 14            Martin, Sandra         Software Engineer
# 15             Monroe, Peter        IT Manager - Infra
# ...

# %% [markdown]
# # Q8. number of employees whose salary is greater then equal to 200000?

# %%
pd.DataFrame(df1[['Employee_Name','Position','EmploymentStatus','PerformanceScore','RecruitmentSource','Salary']]
                [df1['Salary']>=200000])
# Out:
#         Employee_Name         Position EmploymentStatus PerformanceScore  \
# 145       King, Janet  President & CEO           Active      Fully Meets
# 300  Zamora, Jennifer              CIO           Active          Exceeds
#
#      RecruitmentSource  Salary
# 145             Indeed  250000
# 300  Employee Referral  220450

# %% [markdown]
# # Q9. number of employee whose salary is less then 50000?

# %%
pd.DataFrame(df1[['Employee_Name','Position','EmploymentStatus','PerformanceScore','RecruitmentSource','Salary']]
                [df1['Salary']<50000])

# we have found that 32 emplyees salary is less then 50000 
# now on the basis performancescore of these employees we can give them increament in salary 
# all the employees whose salary is less then 50000 are of same position "production technician 1"
# Out:
#              Employee_Name                  Position        EmploymentStatus  \
# 8         Bachiochi, Linda   Production Technician I                  Active
# 11         Barbara, Thomas   Production Technician I  Voluntarily Terminated
# 71       Dobrin, Denisa  S   Production Technician I                  Active
# 78           Engdahl, Jean   Production Technician I                  Active
# 111          Gordon, David   Production Technician I                  Active
# 113          Goyal, Roxana   Production Technician I                  Active
# 122      Heitzman, Anthony   Production Technician I                  Active
# 128        Howard, Estelle  Administrative Assistant    Terminated for Cause
# 135       Jacobi, Hannah     Production Technician I                  Active
# 138        Johnson, George   Production Technician I  Voluntarily Terminated
# 147    Kirill, Alexandra     Production Technician I  Voluntarily Terminated
# ...

# %% [markdown]
# # Q10. description of minimum, mean and maximum Salary on the basis of position?

# %%
Employee_salary_by_position = pd.DataFrame(df1.groupby('Position') 
                            .agg(min_sal = ('Salary', 'min'), 
                                 mean_sal = ('Salary', 'mean'),
                                 max_sal = ('Salary', 'max')).round(2))
Employee_salary_by_position
# Out:
#                               min_sal   mean_sal  max_sal
# Position
# Accountant I                    63000   63507.67    64520
# Administrative Assistant        49920   52280.00    55000
# Area Sales Manager              55875   64932.56    74326
# BI Developer                    90100   95465.00    99020
# BI Director                    110929  110929.00   110929
# CIO                            220450  220450.00   220450
# Data Analyst                    83552   89932.57    93554
# Data Analyst                    88527   88527.00    88527
# Data Architect                 150290  150290.00   150290
# Database Administrator          97999  108499.60   114800
# Director of Operations         170500  170500.00   170500
# Director of Sales              180000  180000.00   180000
# Enterprise Architect           103613  103613.00   103613
# IT Director                    178000  178000.00   178000
# IT Manager - DB                140920  144959.50   148999
# ...

# %% [markdown]
# # Q11.how many employees work under each manager??

# %%
pd.DataFrame(df1['ManagerName'].value_counts())
# Out:
#                     ManagerName
# Michael Albert               22
# Kissy Sullivan               22
# Elijiah Gray                 22
# Kelley Spirea                22
# Brannon Miller               22
# Ketsia Liebig                21
# David Stanley                21
# Amy Dunn                     21
# Janet King                   19
# Simon Roup                   17
# Peter Monroe                 14
# John Smith                   14
# Webster Butler               13
# Lynn Daneault                13
# Alex Sweetwater               9
# Brian Champaigne              8
# Brandon R. LeBlanc            7
# Jennifer Zamora               7
# Eric Dougall                  4
# Debra Houlihan                3
# Board of Directors            2

# %% [markdown]
# # Q12. state wise count of employees ?

# %%
pd.DataFrame(df1['State'].value_counts())
#highest number of employee are from 'MA'
# Out:
#     State
# MA    268
# CT      6
# TX      3
# VT      2
# UT      1
# AZ      1
# ND      1
# OR      1
# MT      1
# NV      1
# ID      1
# KY      1
# NC      1
# FL      1
# GA      1
# CO      1
# NY      1
# PA      1
# RI      1
# NH      1
# TN      1
# IN      1
# OH      1
# CA      1
# WA      1
# AL      1
# VA      1
# ME      1

# %% [markdown]
# # Q13. racism count on the basis racedesc?

# %%
pd.DataFrame(df1['RaceDesc'].value_counts())
# Out:
#                                   RaceDesc
# White                                  183
# Black or African American               79
# Asian                                   26
# Two or more races                       11
# American Indian or Alaska Native         3
# Hispanic                                 1

# %% [markdown]
#  # Q14. how many employees are assigned to more than 6 projects?

# %%
pc=pd.DataFrame(df1[['Employee_Name','Position',
                     'PerformanceScore','SpecialProjectsCount']]
                [df1['SpecialProjectsCount']>=6])
pc.reset_index(drop=True,inplace=True)
pc
# Out:
#                Employee_Name                  Position   PerformanceScore  \
# 0   Ait Sidi, Karthikeyan                      Sr. DBA        Fully Meets
# 1         Bacong, Alejandro                 IT Support        Fully Meets
# 2               Booth, Frank      Enterprise Architect        Fully Meets
# 3                 Brown, Mia              Accountant I        Fully Meets
# 4           Carabbio, Judith         Software Engineer        Fully Meets
# 5           Carr, Claudia  N                   Sr. DBA        Fully Meets
# 6          Champaigne, Brian               BI Director        Fully Meets
# 7              Clayton, Rick                IT Support        Fully Meets
# 8            Costello, Frank              Data Analyst        Fully Meets
# 9             Daniele, Ann        Sr. Network Engineer        Fully Meets
# 10             DeVito, Tommy              BI Developer        Fully Meets
# 11              Dolan, Linda                IT Support        Fully Meets
# ...

# %%
fig, ax = plt.subplots(figsize=(10,5))
_ = plt.scatter(x=df1['Salary'], y=df1['PerformanceScore'], edgecolors="#7FFFD4", linewidths=0.5)
_ = ax.set(xlabel="Views", ylabel="Likes")
_ = plt.title('Performance Score with Salary',fontsize=20)

# %% [markdown]
# # Q15. how many employees is hired from diffrent recrutment sources?

# %%
re=pd.DataFrame(df1['RecruitmentSource'].value_counts())
re
# Out:
#                          RecruitmentSource
# Indeed                                  86
# LinkedIn                                72
# Google Search                           46
# Employee Referral                       31
# Diversity Job Fair                      29
# CareerBuilder                           23
# Website                                 13
# Other                                    2
# On-line Web application                  1

# %%
re.plot.pie(subplots=True,radius = 4.5, autopct = '%1.1f%%')
# Out:
# array([<AxesSubplot:ylabel='RecruitmentSource'>], dtype=object)

# %%
Ea=pd.DataFrame(df1[['Employee_Name','Position',
                     'PerformanceScore','SpecialProjectsCount','Absences']]
                [df1['Absences']>=20])
Ea.reset_index(drop=True,inplace=True)
Ea
# Out:
#               Employee_Name                  Position PerformanceScore  \
# 0             Bates, Norman   Production Technician I      Fully Meets
# 1   Fitzpatrick, Michael  J  Production Technician II      Fully Meets
# 2            Givens, Myriam        Area Sales Manager      Fully Meets
# 3               Goeth, Amon                IT Support      Fully Meets
# 4               Good, Susan  Production Technician II      Fully Meets
# 5           Guilianno, Mike        Area Sales Manager      Fully Meets
# 6          Hankard, Earnest  Production Technician II      Fully Meets
# 7           Kreuger, Freddy        Area Sales Manager      Fully Meets
# 8         Langford, Lindsey  Production Technician II      Fully Meets
# 9           Latif, Mohammed  Production Technician II      Fully Meets
# 10      LeBlanc, Brandon  R   Shared Services Manager      Fully Meets
# 11           Mckenna, Sandy   Production Technician I      Fully Meets
# ...

# %%
df1.loc[(df1['PerformanceScore']=='Fully Meets') & (df1['RecruitmentSource'].str.startswith('L')),
                ['Employee_Name','Position','PerformanceScore','RecruitmentSource']]
# Out:
#             Employee_Name                  Position PerformanceScore  \
# 2       Akinkuolie, Sarah  Production Technician II      Fully Meets
# 6         Andreola, Colby         Software Engineer      Fully Meets
# 24           Booth, Frank      Enterprise Architect      Fully Meets
# 36       Carey, Michael     Production Technician I      Fully Meets
# 37       Carr, Claudia  N                   Sr. DBA      Fully Meets
# 55      Crimmings,   Jean   Production Technician I      Fully Meets
# 58         Daniele, Ann        Sr. Network Engineer      Fully Meets
# 60          Davis, Daniel  Production Technician II      Fully Meets
# 78          Engdahl, Jean   Production Technician I      Fully Meets
# 84         Faller, Megan   Production Technician II      Fully Meets
# 95            Galia, Lisa                IT Support      Fully Meets
# 97          Gaul, Barbara   Production Technician I      Fully Meets
# 98        Gentry, Mildred   Production Technician I      Fully Meets
# ...

# %%
a=df1.loc[(df1['PerformanceScore']=='Fully Meets') & (df1['RecruitmentSource'].str.startswith('I')),
                ['Employee_Name','Position','PerformanceScore','RecruitmentSource']]

a.reset_index(drop=True)
# Out:
#                Employee_Name                 Position PerformanceScore  \
# 0   Ait Sidi, Karthikeyan                     Sr. DBA      Fully Meets
# 1               Alagbe,Trina  Production Technician I      Fully Meets
# 2         Bacong, Alejandro                IT Support      Fully Meets
# 3            Biden, Lowan  M  Production Technician I      Fully Meets
# 4             Bozzi, Charles       Production Manager      Fully Meets
# ..                       ...                      ...              ...
# 60          Terry, Sharlene        Area Sales Manager      Fully Meets
# 61        Theamstern, Sophia  Production Technician I      Fully Meets
# 62         Tippett, Jeanette  Production Technician I      Fully Meets
# 63           Valentin,Jackie       Area Sales Manager      Fully Meets
# 64             Wang, Charlie      Senior BI Developer      Fully Meets
#
#    RecruitmentSource
# 0             Indeed
# 1             Indeed
# 2             Indeed
# 3             Indeed
# ...

# %%
df1.loc[(df1['PerformanceScore']=='Fully Meets') & (df1['RecruitmentSource'].str.startswith('W')),
                ['Employee_Name','Position','PerformanceScore','RecruitmentSource']]
# Out:
#             Employee_Name                  Position PerformanceScore  \
# 155  LaRotonda, William                Accountant I      Fully Meets
# 161      Leruth, Giovanni        Area Sales Manager      Fully Meets
# 168        Lydon, Allison   Production Technician I      Fully Meets
# 178         McKinzie, Jac        Area Sales Manager      Fully Meets
# 204         Ozark, Travis        Area Sales Manager      Fully Meets
# 217           Potts, Xana        Area Sales Manager      Fully Meets
# 234        Rose, Ashley     Production Technician I      Fully Meets
# 247           Singh, Nan   Administrative Assistant      Fully Meets
# 283      Villanueva, Noah        Area Sales Manager      Fully Meets
# 293         Wilber, Barry   Production Technician I      Fully Meets
#
#     RecruitmentSource
# 155           Website
# 161           Website
# 168           Website
# 178           Website
# 204           Website
# 217           Website
# 234           Website
# ...

# %%
df1.loc[(df1['PerformanceScore']=='Fully Meets') & (df1['RecruitmentSource'].str.startswith('G')),
                ['Employee_Name','Position','PerformanceScore','RecruitmentSource']]
# Out:
#                Employee_Name                      Position PerformanceScore  \
# 4           Anderson, Carol        Production Technician I      Fully Meets
# 13      Barone, Francesco  A       Production Technician I      Fully Meets
# 15             Bates, Norman       Production Technician I      Fully Meets
# 17       Beatrice, Courtney        Production Technician I      Fully Meets
# 18             Becker, Renee        Database Administrator      Fully Meets
# 19           Bernstein, Sean       Production Technician I      Fully Meets
# 23           Bondwell, Betsy      Production Technician II      Fully Meets
# 27              Brill, Donna       Production Technician I      Fully Meets
# 30          Bunbury, Jessica            Area Sales Manager      Fully Meets
# 33                Cady, Max   Software Engineering Manager      Fully Meets
# 39          Chace, Beatrice        Production Technician I      Fully Meets
# ...

# %%
df1.loc[(df1['PerformanceScore']=='Fully Meets') & (df1['RecruitmentSource'].str.startswith('E')),
                ['Employee_Name','Position','PerformanceScore','RecruitmentSource']]
# Out:
#          Employee_Name                  Position PerformanceScore  \
# 7          Athwal, Sam   Production Technician I      Fully Meets
# 31       Burke, Joelle  Production Technician II      Fully Meets
# 42      Chigurh, Anton        Area Sales Manager      Fully Meets
# 49       Cockel, James   Production Technician I      Fully Meets
# 56         Cross, Noah      Sr. Network Engineer      Fully Meets
# 72        Dolan, Linda                IT Support      Fully Meets
# 79        England, Rex   Production Technician I      Fully Meets
# 96        Garcia, Raul   Production Technician I      Fully Meets
# 109    Gonzalez, Maria                IT Support      Fully Meets
# 114    Gray, Elijiah          Production Manager      Fully Meets
# 135   Jacobi, Hannah     Production Technician I      Fully Meets
# 151     Lajiri,  Jyoti      Sr. Network Engineer      Fully Meets
# 152        Landa, Hans        Production Manager      Fully Meets
# ...

# %%
df1.loc[(df1['PerformanceScore']=='Fully Meets') & (df1['RecruitmentSource'].str.startswith('D')),
                ['Employee_Name','Position','PerformanceScore','RecruitmentSource']]
# Out:
#              Employee_Name                  Position PerformanceScore  \
# 8         Bachiochi, Linda   Production Technician I      Fully Meets
# 10    Baczenski, Rachael     Production Technician I      Fully Meets
# 11         Barbara, Thomas   Production Technician I      Fully Meets
# 25       Boutwell, Bonalyn            Sr. Accountant      Fully Meets
# 28              Brown, Mia              Accountant I      Fully Meets
# 29      Bugali, Josephine    Production Technician I      Fully Meets
# 99           Gerke, Melisa   Production Technician I      Fully Meets
# 150        Kreuger, Freddy        Area Sales Manager      Fully Meets
# 179       Meads, Elizabeth   Production Technician I      Fully Meets
# 186         Moran, Patrick  Production Technician II      Fully Meets
# 192         Ndzi, Colombui   Production Technician I      Fully Meets
# 221            Quinn, Sean         Software Engineer      Fully Meets
# ...

# %%
df1.loc[(df1['PerformanceScore']=='Fully Meets') & (df1['RecruitmentSource'].str.startswith('C')),
                ['Employee_Name','Position','PerformanceScore','RecruitmentSource']]
# Out:
#              Employee_Name                  Position PerformanceScore  \
# 63       Del Bosque, Keyla         Software Engineer      Fully Meets
# 71       Dobrin, Denisa  S   Production Technician I      Fully Meets
# 94          Fraval, Maruk         Area Sales Manager      Fully Meets
# 100        Gill, Whitney          Area Sales Manager      Fully Meets
# 115           Gross, Paula   Production Technician I      Fully Meets
# 120  Harrington, Christie    Production Technician I      Fully Meets
# 123     Hendrickson, Trina  Production Technician II      Fully Meets
# 141           Jung, Judy     Production Technician I      Fully Meets
# 158          Leach, Dallas   Production Technician I      Fully Meets
# 159    LeBlanc, Brandon  R   Shared Services Manager      Fully Meets
# 177         Mckenna, Sandy   Production Technician I      Fully Meets
# 180     Medeiros, Jennifer   Production Technician I      Fully Meets
# ...

# %%
df1.loc[(df1['PerformanceScore']=='Fully Meets') & (df1['RecruitmentSource'].str.startswith('O')),
                ['Employee_Name','Position','PerformanceScore','RecruitmentSource']]
# Out:
#          Employee_Name                  Position PerformanceScore  \
# 14       Barton, Nader   Production Technician I      Fully Meets
# 93   Foster-Baker, Amy            Sr. Accountant      Fully Meets
# 272   Thibaud, Kenneth  Production Technician II      Fully Meets
#
#            RecruitmentSource
# 14   On-line Web application
# 93                     Other
# 272                    Other

# %% [markdown]
# # Applying Machine learning

# %%
df2=df[['EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
        'EmpStatusID', 'DeptID', 'Salary', 'PositionID','SpecialProjectsCount', 'Absences', 'PerfScoreID']]
#df2.reset_index(drop=True,inplace=True)
df2
# Out:
#      EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  DeptID  Salary  \
# 0    10026          0                0         1            1       5   62506
# 1    10084          1                1         1            5       3  104437
# 2    10196          1                1         0            5       5   64955
# 3    10088          1                1         0            1       5   64991
# 4    10069          0                2         0            5       5   50825
# ..     ...        ...              ...       ...          ...     ...     ...
# 306  10135          0                0         1            1       5   65893
# 307  10301          0                0         0            5       5   48513
# 308  10010          0                0         0            1       3  220450
# 309  10043          0                0         0            1       3   89292
# 310  10271          0                4         0            1       5   45046
#
# ...

# %%
df2.dtypes
# Out:
# EmpID                   int64
# MarriedID               int64
# MaritalStatusID         int64
# GenderID                int64
# EmpStatusID             int64
# DeptID                  int64
# Salary                  int64
# PositionID              int64
# SpecialProjectsCount    int64
# Absences                int64
# PerfScoreID             int64
# dtype: object

# %%
df1['PerformanceScore'].value_counts()
#if output is 1 that means fullymeets 
#if 2 then exceed
# if 3 need improvement
#if4 then pip
# Out:
# Fully Meets          236
# Exceeds               36
# Needs Improvement     18
# PIP                   13
# Name: PerformanceScore, dtype: int64

# %% [markdown]
# # Logistic Regression Technique

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
x=df2.iloc[:,0:11]
y=df1.iloc[:,8]
y
# Out:
# 0          Exceeds
# 1      Fully Meets
# 2      Fully Meets
# 3      Fully Meets
# 4      Fully Meets
#           ...
# 298    Fully Meets
# 299            PIP
# 300        Exceeds
# 301    Fully Meets
# 302    Fully Meets
# Name: PerformanceScore, Length: 303, dtype: object

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=0,stratify=df['PerformanceScore'])

# %%
xtrain.shape
# Out:
# (242, 11)

# %%
ytrain.shape
# Out:
# (242,)

# %%
xtest.shape
# Out:
# (61, 11)

# %%
ytest.shape
# Out:
# (61,)

# %%
model=LogisticRegression()
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
predict=model.predict(xtest)

# %%
newresult=model.predict([[10026,0,0,1,1,5,62506,19,0,1,1]])
print(newresult)
# Out:
# ['Fully Meets']

# %%
model.score(xtest,ytest)
# Out:
# 0.7704918032786885

# %%
accuracy_score(ytest,predict)
# Out:
# 0.7704918032786885

# %%
confusion_matrix(ytest,predict)
# Out:
# array([[ 0,  7,  0,  0],
#        [ 0, 47,  0,  0],
#        [ 0,  4,  0,  0],
#        [ 0,  3,  0,  0]], dtype=int64)

# %%
print(classification_report(ytest,predict))
# Out:
#                    precision    recall  f1-score   support
#
#           Exceeds       0.00      0.00      0.00         7
#       Fully Meets       0.77      1.00      0.87        47
# Needs Improvement       0.00      0.00      0.00         4
#               PIP       0.00      0.00      0.00         3
#
#          accuracy                           0.77        61
#         macro avg       0.19      0.25      0.22        61
#      weighted avg       0.59      0.77      0.67        61
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # Conclusions

# %% [markdown]
# We have drawn many interesting inferences from the dataset employee_dataset; here’s a summary of the few of them
#
# 1. The ratio of the employees are femal worker are more then male workers
# 2. The maitial status of the employee are most number of employee are single 132 then married are 122 & divorced 30,seprated 11 and widow 8
# 3. The total number of employees are 303 but active employees are only 199 so growth or hike in salary is applyede for 199n employee
# 4. Most of the employee are working in Production team
# 5. performance of employee are most of the employees have performanc _score is Fully Meet
# 6. so in  this data st we are seen that performance scor is useed to decide wh will get salary  hik or who will not
